# %% [markdown]
# # Piotr Mamos

# %% [markdown]
# # Zadanie 3
# Zdefiniuj poniższą funkcję i sporządź jej wykres dla argumentów z danego przedziału:
#
# $f(x)=x^2+5$
#
# $x>-1 oraz x<1$
# $x>-6 oraz x<6$
# $x>0 oraz x<5$
# Wspierając się dokumentacją Matplotlib. Dodaj do wykresu etykiety osi, tytuły wykresów i legendy.
#
# Wskazówki: Deklaracja funkcji w Python.
#
# W Pythonie bloki kodu (w tym również funkcje) są wyróżniane za pomocą wcięć. Do wizualizacji wyników w Pythonie używa się pakietu Matplotlib.
#
# W pliku mają być zawarte: imię, nazwisko, opis wykonywanego ćwiczenia - formatowanie markdown w poszczególnych komórkach.

# %%
import numpy as np
import scipy
import matplotlib
import pandas as pd

import matplotlib.pyplot as plt

# %%
y = lambda x: x**2+5

# %%
def my_plot(x,y,xlabel,ylabel,title,label):
    if x.shape != y.shape or  min(x.shape)==0:
        return None
    fig, ax = plt.subplots()
    ax.plot(x, y, 'r', label=label)
    ax.set(xlabel=xlabel, ylabel=ylabel, title=title)
    ax.grid()
    ax.legend()
    return fig
x=np.linspace(-1,1)
my_plot(x,y(x),"x","y","x^2+5, w zakresie od -1 do 1","x^2+5")
x=np.linspace(-6,6)
my_plot(x,y(x),"x","y","x^2+5, w zakresie od -6 do 6","x^2+5")
x=np.linspace(0,5)
my_plot(x,y(x),"x","y","x^2+5, w zakresie od 0 do 5","x^2+5")
plt.show()

# %% [markdown]
# # Zadanie 4
# Utwórz dataframe, w którym kolumny mają nazwy: name, surname, age, sex. Uzupełnij pięcioma dowolnymi rekordami oraz wyświetl informacje o danych pandas .info(), opis danych pandas .describe(), wyświetl pierwsze trzy rekordy pandas .head().

# %%
data1 = {'name':["Ola","Jan","Stefan","Monika","Maciek"],"surname":["Nowak","Kowalski","Nowicki","Nuta","Wójcik"],"age":[12,45,32,23,19],"sex":["Female","Male","Male","Female","Male"]}
df = pd.DataFrame(data = data1)
df
# Out:
#      name   surname  age     sex
# 0     Ola     Nowak   12  Female
# 1     Jan  Kowalski   45    Male
# 2  Stefan   Nowicki   32    Male
# 3  Monika      Nuta   23  Female
# 4  Maciek    Wójcik   19    Male

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   surname  5 non-null      object
#  2   age      5 non-null      int64
#  3   sex      5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 288.0+ bytes

# %%
df.describe()
# Out:
#              age
# count   5.000000
# mean   26.200000
# std    12.755391
# min    12.000000
# 25%    19.000000
# 50%    23.000000
# 75%    32.000000
# max    45.000000

# %%
df.head(3)
# Out:
#      name   surname  age     sex
# 0     Ola     Nowak   12  Female
# 1     Jan  Kowalski   45    Male
# 2  Stefan   Nowicki   32    Male
